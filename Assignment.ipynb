# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv("Cardiotocographic.csv")
df
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %%
df.isnull().sum()
# Out:
# LB          21
# AC          20
# FM           0
# UC           0
# DL           0
# DS          21
# DP          21
# ASTV         0
# MSTV         0
# ALTV         0
# MLTV        21
# Width       21
# Tendency    21
# NSP         21
# dtype: int64

# %%
df= df.dropna()

# %%
df.isnull().sum()
# Out:
# LB          0
# AC          0
# FM          0
# UC          0
# DL          0
# DS          0
# DP          0
# ASTV        0
# MSTV        0
# ALTV        0
# MLTV        0
# Width       0
# Tendency    0
# NSP         0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2105 entries, 0 to 2125
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   LB        2105 non-null   float64
#  1   AC        2105 non-null   float64
#  2   FM        2105 non-null   float64
#  3   UC        2105 non-null   float64
#  4   DL        2105 non-null   float64
#  5   DS        2105 non-null   float64
#  6   DP        2105 non-null   float64
#  7   ASTV      2105 non-null   float64
#  8   MSTV      2105 non-null   float64
#  9   ALTV      2105 non-null   float64
#  10  MLTV      2105 non-null   float64
#  11  Width     2105 non-null   float64
#  12  Tendency  2105 non-null   float64
#  13  NSP       2105 non-null   float64
# dtypes: float64(14)
# memory usage: 246.7 KB

# %%
df
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %%
df.describe()
# Out:
#                 LB           AC           FM           UC           DL  \
# count  2105.000000  2105.000000  2105.000000  2105.000000  2105.000000
# mean    133.343598     0.003202     0.009963     0.004388     0.001892
# std      11.270154     0.004324     0.067870     0.003350     0.003348
# min      51.842487    -0.019284    -0.480634    -0.014925    -0.015393
# 25%     126.000000     0.000000     0.000000     0.001838     0.000000
# 50%     133.000000     0.001631     0.000000     0.004484     0.000000
# 75%     140.000000     0.005650     0.002554     0.006536     0.003289
# max     214.000000     0.038567     0.961268     0.030002     0.030769
#
#                 DS           DP         ASTV         MSTV         ALTV  \
# count  2105.000000  2105.000000  2105.000000  2105.000000  2105.000000
# mean      0.000003     0.000175    46.996929     1.361006    10.353647
# std       0.000142     0.000840    18.847737     1.173164    21.282102
# ...

# %%
df = pd.DataFrame(data, columns=[f'Attr_{i+1}' for i in range(14)])

Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1

outliers = (df < (Q1 - 1.5 * IQR)) | (df > (Q3 + 1.5 * IQR))

outlier_counts = outliers.sum()
outlier_counts
# Out:
# Attr_1      4
# Attr_2     11
# Attr_3     16
# Attr_4      5
# Attr_5     14
# Attr_6     17
# Attr_7     13
# Attr_8     18
# Attr_9     15
# Attr_10    14
# Attr_11     9
# Attr_12    14
# Attr_13    10
# Attr_14    19
# dtype: int64

# %%
import matplotlib.pyplot as plt

df.boxplot(figsize=(15, 5), rot=90)
plt.title("Boxplot for Outlier Detection")
plt.show()

# %%
df_imputed = df.copy()
for col in df.columns:
    median = df[col].median()
    df_imputed[col] = np.where((df[col] < Q1[col]) | (df[col] > Q3[col]), median, df[col])

# %%
df_imputed.boxplot(figsize=(15, 5), rot=90)
plt.title("Boxplot for Outlier Detection")
plt.show()

# %%
df_imputed.describe()
# Out:
#             Attr_1       Attr_2       Attr_3       Attr_4       Attr_5  \
# count  2105.000000  2105.000000  2105.000000  2105.000000  2105.000000
# mean     -0.039802    -0.018664    -0.014531    -0.018808    -0.024246
# std       0.268380     0.265315     0.274873     0.268124     0.270037
# min      -0.704357    -0.682689    -0.706616    -0.705242    -0.704601
# 25%      -0.038923    -0.019183    -0.016239    -0.027857    -0.027211
# 50%      -0.038923    -0.019183    -0.016239    -0.027857    -0.027211
# 75%      -0.038923    -0.019183    -0.016239    -0.027857    -0.027211
# max       0.661553     0.672786     0.690729     0.672537     0.659644
#
#             Attr_6       Attr_7       Attr_8       Attr_9      Attr_10  \
# count  2105.000000  2105.000000  2105.000000  2105.000000  2105.000000
# mean     -0.025852    -0.000639    -0.004812     0.002144    -0.041302
# std       0.261097     0.267167     0.266891     0.248666     0.278600
# ...

# %%
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.boxplot(data=df_imputed, palette="Set2")
plt.title("Boxplots of Numerical Variables")
plt.xlabel("Variables")
plt.ylabel("Values")
plt.show()

# %%
# 2.Statistical Summary:
df.describe()
# Out:
#             Attr_1       Attr_2       Attr_3       Attr_4       Attr_5  \
# count  2105.000000  2105.000000  2105.000000  2105.000000  2105.000000
# mean     -0.034529    -0.008269    -0.026666    -0.003175    -0.023376
# std       0.971863     1.007207     1.026644     0.984459     1.016466
# min      -2.911518    -3.533304    -4.014014    -3.130780    -4.352101
# 25%      -0.704357    -0.682689    -0.706616    -0.705242    -0.704601
# 50%      -0.038923    -0.019183    -0.016239    -0.027857    -0.027211
# 75%       0.661553     0.672786     0.690729     0.672537     0.659644
# max       2.731583     4.060472     3.531615     3.310254     3.302333
#
#             Attr_6       Attr_7       Attr_8       Attr_9      Attr_10  \
# count  2105.000000  2105.000000  2105.000000  2105.000000  2105.000000
# mean     -0.015681     0.007046    -0.004349     0.012292    -0.016497
# std       0.999810     0.999159     1.000563     0.974305     1.016490
# ...

# %%
# 3.Data Visualization:

# %%
# Create histograms or boxplots to visualize the distributions of various numerical variables.
df_imputed.hist(figsize=(30, 16), bins=10, color='skyblue', edgecolor='black')
plt.suptitle("Histograms of Numerical Variables")
plt.show()

# %%
# Use bar charts or pie charts to display the frequency of categories for categorical variables.

# Count frequency of each category in 'Category' column
category_counts = df_imputed['Category'].value_counts()

# Plot bar chart
plt.figure(figsize=(8, 6))
sns.barplot(x=category_counts.index, y=category_counts.values, palette="viridis")
plt.title("Bar Chart of Category Frequency", fontsize=14)
plt.xlabel("Categories", fontsize=12)
plt.ylabel("Frequency", fontsize=12)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Category'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[65], line 4
# ...

# %%
print(df_imputed.columns)
# Out:
# Index(['Attr_1', 'Attr_2', 'Attr_3', 'Attr_4', 'Attr_5', 'Attr_6', 'Attr_7',
#        'Attr_8', 'Attr_9', 'Attr_10', 'Attr_11', 'Attr_12', 'Attr_13',
#        'Attr_14'],
#       dtype='object')

# %%
print(df_imputed.head())
# Out:
#      Attr_1    Attr_2    Attr_3    Attr_4    Attr_5    Attr_6    Attr_7  \
# 0 -0.038923 -0.019183 -0.020991  0.343876  0.206764 -0.029333 -0.002696
# 1 -0.038923 -0.019183  0.005905 -0.156502  0.104833 -0.029333  0.357928
# 2 -0.038923 -0.019183  0.322136 -0.027857 -0.027211 -0.527632 -0.390201
# 3 -0.038923  0.372084 -0.016239  0.517201  0.235436 -0.029333 -0.661581
# 4 -0.147380 -0.669258 -0.027252 -0.323826 -0.027211 -0.160394 -0.550289
#
#      Attr_8    Attr_9   Attr_10   Attr_11   Attr_12   Attr_13   Attr_14
# 0 -0.009696  0.006658 -0.340556 -0.515206  0.026041 -0.007046 -0.040272
# 1  0.202435  0.006658 -0.002489  0.016813  0.026041  0.305674 -0.040272
# 2 -0.009696  0.006658  0.382644  0.016813  0.321406 -0.007046 -0.040272
# 3 -0.009696 -0.410977 -0.313591 -0.036745 -0.192696 -0.007046 -0.040272
# 4 -0.009696  0.006658  0.606485  0.016813 -0.291669 -0.007046  0.185687

# %%
category_counts = df_imputed['Category1'].value_counts()

# Plot bar chart
plt.figure(figsize=(8, 6))
sns.barplot(x=category_counts.index, y=category_counts.values, palette="viridis")
plt.title("Bar Chart of Category Frequency", fontsize=14)
plt.xlabel("Categories", fontsize=12)
plt.ylabel("Frequency", fontsize=12)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Category1'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[68], line 1
# ...
